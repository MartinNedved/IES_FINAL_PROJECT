# %%
import json
import pandas as pd
from datetime import datetime



index_lists=pd.read_json('clear_timeseries.json') # converts the json processed file into pandas dataframe

financial_lists=pd.read_json('clear_financials.json')

company_overview_list=pd.read_json('clear_overview.json')

#print(company_overview_list.T['Industry'].loc['CVS'])
#print(company_overview_list.T.index.tolist())


#list_of_companies=company_overview_list.T.index.tolist()
#industry_list=[]
#for i in list_of_companies:
    #if company_overview_list.T['Industry'].loc[i] not in (industry_list):          we do this in order to get a list of industries
        #industry_list.append(company_overview_list.T['Industry'].loc[i])
#print (industry_list)      

#list_of_companies=company_overview_list.T.index.tolist()
#sector_list=[]
#for i in list_of_companies:
    #if company_overview_list.T['Sector'].loc[i] not in (sector_list):          #we do this in order to get a list of industries
        #sector_list.append(company_overview_list.T['Sector'].loc[i])
#print (sector_list)    


#print((financial_lists['CVS'].loc[2019])['priceToEarningsRatio'])

#index_lists['^NDX'][2000][0]


#INSTRUCTIONS:
# index = '^GSPC' (S&P)>2000-2019, '^NDX' (Nasdaq)>2000-2019, '^DJI' (dowjones)>2004,2008,2009,2012,2013,2015,2017,2018,2019,2020
# year = 2000-2019
# parameter = 'priceToEarningsRatio' (P/E), 'marketCapitalization' (market cap), 'netIncome' (net income), 'Industry' (['Financial Data & Stock Exchanges', 'Telecom Services', 'Oil & Gas E&P', 'Pharmaceutical Retailers', 'Other', 'Software-Application', 'Internet Content & Information', 'Electrical Equipment & Parts', 'Insurance-Life', 'Semiconductor Equipment & Materials', 'Utilities-Regulated Gas', 'Staffing & Employment Services', 'Shell Companies', 'Biotechnology', 'Computer Hardware', 'Information Technology Services', 'Agricultural Inputs', 'Broadcasting', 'Specialty Retail', 'Resorts & Casinos', 'REIT-Office', 'Utilities-Regulated Water', 'Utilities-Regulated Electric', 'Electronic Components', 'Oil & Gas Integrated', 'Personal Services', 'Steel', 'Building Products & Equipment', 'Oil & Gas Equipment & Services', 'Semiconductors', 'Insurance Brokers', 'Aerospace & Defense', 'Software-Infrastructure', 'Asset Management', 'Credit Services', 'Consumer Electronics', 'Beverages-Non-Alcoholic', 'Oil & Gas Midstream', 'Tobacco', 'Healthcare Plans', 'Specialty Industrial Machinery', 'REIT-Healthcare Facilities', 'Gold', 'Trucking', 'Utilities-Diversified', 'Apparel Retail', 'Oil & Gas Drilling', 'Rental & Leasing Services', 'Scientific & Technical Instruments', 'Apparel Manufacturing', 'Industrial Distribution', 'Packaging & Containers', 'Electronic Gaming & Multimedia', 'Auto Parts', 'Capital Markets', 'Medical Care Facilities', 'Gambling', 'REIT-Retail', 'Communication Equipment', 'Internet Retail', 'Medical Devices', 'Integrated Freight & Logistics', 'Footwear & Accessories', 'Financial Conglomerates', 'Drug Manufacturers-Specialty & Generic', 'Restaurants', 'Specialty Business Services', 'Diagnostics & Research', 'Drug Manufacturers-General', 'Other Industrial Metals & Mining', 'Medical Instruments & Supplies', 'Specialty Chemicals', 'REIT-Industrial', 'Insurance-Property & Casualty', 'Packaged Foods', 'Security & Protection Services', 'Chemicals', 'Beverages-Brewers', 'Banks-Regional', 'Auto Manufacturers', 'Confectioners', 'Luxury Goods', 'Travel Services', 'Furnishings, Fixtures & Appliances', 'Entertainment', 'Consulting Services', 'Farm Products', 'Home Improvement Retail', 'Insurance-Specialty']),"Sector" ['Financial Services', 'Communication Services', 'Energy', 'Healthcare', 'Other', 'Technology', 'Industrials', 'Utilities', 'Basic Materials', 'Consumer Cyclical', 'Real Estate', 'Consumer Defensive'])
# criterion = 'highest'/'lowest'
# size = number of companies in the output portfolio ([0:20])

criterion_list=['highest','lowest','whole']
index_list=['^GSPC','^NDX','^DJI']
param_dict={'priceToEarningsRatio':'lowest', 'marketCapitalization':'highest', 'netIncome': 'highest', 'Industry': ['Financial Data & Stock Exchanges', 'Telecom Services', 'Oil & Gas E&P', 'Pharmaceutical Retailers', 'Other', 'Software-Application', 'Internet Content & Information', 'Electrical Equipment & Parts', 'Insurance-Life', 'Semiconductor Equipment & Materials', 'Utilities-Regulated Gas', 'Staffing & Employment Services', 'Shell Companies', 'Biotechnology', 'Computer Hardware', 'Information Technology Services', 'Agricultural Inputs', 'Broadcasting', 'Specialty Retail', 'Resorts & Casinos', 'REIT-Office', 'Utilities-Regulated Water', 'Utilities-Regulated Electric', 'Electronic Components', 'Oil & Gas Integrated', 'Personal Services', 'Steel', 'Building Products & Equipment', 'Oil & Gas Equipment & Services', 'Semiconductors', 'Insurance Brokers', 'Aerospace & Defense', 'Software-Infrastructure', 'Asset Management', 'Credit Services', 'Consumer Electronics', 'Beverages-Non-Alcoholic', 'Oil & Gas Midstream', 'Tobacco', 'Healthcare Plans', 'Specialty Industrial Machinery', 'REIT-Healthcare Facilities', 'Gold', 'Trucking', 'Utilities-Diversified', 'Apparel Retail', 'Oil & Gas Drilling', 'Rental & Leasing Services', 'Scientific & Technical Instruments', 'Apparel Manufacturing', 'Industrial Distribution', 'Packaging & Containers', 'Electronic Gaming & Multimedia', 'Auto Parts', 'Capital Markets', 'Medical Care Facilities', 'Gambling', 'REIT-Retail', 'Communication Equipment', 'Internet Retail', 'Medical Devices', 'Integrated Freight & Logistics', 'Footwear & Accessories', 'Financial Conglomerates', 'Drug Manufacturers-Specialty & Generic', 'Restaurants', 'Specialty Business Services', 'Diagnostics & Research', 'Drug Manufacturers-General', 'Other Industrial Metals & Mining', 'Medical Instruments & Supplies', 'Specialty Chemicals', 'REIT-Industrial', 'Insurance-Property & Casualty', 'Packaged Foods', 'Security & Protection Services', 'Chemicals', 'Beverages-Brewers', 'Banks-Regional', 'Auto Manufacturers', 'Confectioners', 'Luxury Goods', 'Travel Services', 'Furnishings, Fixtures & Appliances', 'Entertainment', 'Consulting Services', 'Farm Products', 'Home Improvement Retail', 'Insurance-Specialty'],"Sector":['Financial Services', 'Communication Services', 'Energy', 'Healthcare', 'Other', 'Technology', 'Industrials', 'Utilities', 'Basic Materials', 'Consumer Cyclical', 'Real Estate', 'Consumer Defensive']}
#parameter_list={'priceToEarningsRatio':'PERatio','marketCapitalization':'MarketCapitalization','netIncome':'EBITDA'} #net income replaced here by EBITDA

def create_portfolio(index,year,parameter,criterion,size):
    
    if (year>2019 or year <2000) or (index not in index_list) or ((parameter not in param_dict.keys()) and (parameter not in param_dict['Industry']) and (parameter not in param_dict['Sector'])) or ((size>20)  or (size <1)) or (criterion not in criterion_list):        
        print("Try again with valid inputs according to the text above.")
        return
    
    company_list=index_lists[index][year]
    
    output_list={}
    output_list_final=[]
    
    if index_lists.isnull()[index][year]:
        print("No info available. Try again with different index/year combination.")   #input data correction if necessary
        return
        
    if (parameter in param_dict['Industry']):
        for company in company_list:
            try:
                if company_overview_list[company]['Industry']==parameter:
                    output_list_final.append(company)
            except KeyError:
                        continue
    elif (parameter in param_dict['Sector']):
        for company in company_list:
            try:
                if company_overview_list[company]['Sector']==parameter:
                    output_list_final.append(company)
            except KeyError:
                        continue
    elif criterion!='whole': 
        
        for company in company_list:
            try:
                if not (financial_lists.isnull()[company].loc[year]):         # against NaN values in financial_lists
                    
                    try:
                        output_list[company]=((financial_lists[company].loc[year])[parameter])
                    
                    except Exception:
                        continue
            except KeyError:
                continue   
            
                    
        if criterion=='highest':
            output_list=sorted(output_list.items(), key=lambda x: x[1],reverse=True) 
            
        elif criterion =='lowest':
            output_list = dict((k, v) for k, v in output_list.items() if v >= 0)
            output_list=sorted(output_list.items(), key=lambda x: x[1])
            
  
        for x in range(size):
            output_list_final.append(output_list[x][0])
            
            
    if ((parameter in param_dict['Industry']) or (parameter in param_dict['Sector'])): 
        return(output_list_final)

    elif ((criterion=='whole') and (parameter not in param_dict['Industry']) and (parameter not in param_dict['Sector'])):
        return(company_list)
    
    else:
        return(output_list_final[0:size])
    

create_portfolio('^DJI',2019,'marketCapitalization','whole',5)
# Out:
# ['MMM',
#  'PG',
#  'MRK',
#  'BA',
#  'CAT',
#  'DIS',
#  'MSFT',
#  'IBM',
#  'JPM',
#  'JNJ',
#  'INTC',
#  'MCD',
#  'HD',
#  'AXP',
#  'WMT',
#  'KO',
#  'RTX',
#  'XOM',
#  'GE',
#  'DD',
#  'HPQ',
#  'HWM',
#  'GM',
#  'C',
#  'HON',
#  'MO',
#  'IP']

# %%
import matplotlib.pyplot as plt
import numpy as np

with open('clear_financials.json', 'r') as fin_f, \
    open('clear_time_series_monthly_adjusted.json', 'r') as month_f: 
    financials = json.load(fin_f)
    monthly_adjusted = json.load(month_f)
    
for company, prices in monthly_adjusted.items():
    temp = {}
    for date, price in prices.items():
        temp[datetime.strptime(date, '%Y-%m-%d')] = float(price)
    monthly_adjusted[company] = temp

def get_price_from_year_start(symbol, year):
    try:
        year_prices = {x: y for x, y in monthly_adjusted[symbol].items() if x.year==year}
        return year_prices[min(year_prices)]
    except Exception:
        print(f"{symbol} not in financials_monthly_{year}")
        return(0)

def get_companies_market_cap_dict(symbols, year):
    companies_cap = {}
    for symbol in symbols:
        try:
            companies_cap[symbol] = financials[symbol][str(year)]['marketCapitalization']
        except Exception:
            print(f"{symbol} not in financials_clear financials_{year}")
            companies_cap[symbol]=0
       
    return companies_cap

def sell_portfolio(portfolio, year):
    amount = 0
    for symbol, num_shares in portfolio.items():
        amount += get_price_from_year_start(symbol, year)*num_shares
    return amount

def buy_portfolio(symbols, year, budget):
    companies_cap = get_companies_market_cap_dict(symbols, year)
    
    total_cap = sum(companies_cap.values())
    weight = budget / total_cap
    portfolio = {}
    for symbol, cap in companies_cap.items():
        price=get_price_from_year_start(symbol, year)
        if price!=0:
            
            portfolio[symbol] = (cap*weight)  / price  #for each symbol we have number of shares acquired
    
    return portfolio
    



def invest (index,start_year,parameter,criterion,size,budget):        

    portfolio_history={}
    portfolio_history[start_year]=budget
    portfolio_structure=[]
    
    for year in (range(start_year,2020)):          
        
        if year>start_year:
            portfolio_history[year]=sell_portfolio(portfolio,year)
        
        if year<2019:
            
            portfolio_structure=create_portfolio(index,year,parameter,criterion,size)
            
            portfolio=buy_portfolio(portfolio_structure,year,budget)
            #print(portfolio)
            
        #print (portfolio_history)
    
    return(portfolio_history)
    
portfolio_history_SP=invest('^GSPC',2001,'priceToEarningsRatio','whole',3,100)
#portfolio_history_NAS=invest('^NDX',2001,'priceToEarningsRatio','whole',3,100)
#portfolio_history_DJI=invest('^DJI',2001,'priceToEarningsRatio','whole',3,100)
#portfolio_history_tech=invest('^GSPC',2001,'Technology','whole',3,100)
#portfolio_history_health=invest('^GSPC',2001,'Healthcare','whole',3,100)

portfolio_history=invest('^NDX',2001,'priceToEarningsRatio','lowest',20,100)


index_dict={}


variables=sorted(portfolio_history.items())
variables_SP=sorted(portfolio_history_SP.items())
#variables_NAS=sorted(portfolio_history_NAS.items())
#variables_DJI=sorted(portfolio_history_DJI.items())
#variables_tech=sorted(portfolio_history_tech.items())
#variables_health=sorted(portfolio_history_health.items())


(a, b) = zip(*variables) 
(c, d )= zip(*variables_SP)
#(e, f )= zip(*variables_NAS)
#(g, h )= zip(*variables_DJI)
#(i, j )= zip(*variables_tech)
#(k, l )= zip(*variables_health)
plt.plot(a, b)
plt.plot(c, d)
#plt.plot(e, f)
#plt.plot(g, h)
#plt.plot(i, j)
#plt.plot(k, l)


plt.xticks(list(portfolio_history.keys()))  

plt.rc('figure', figsize=(25, 25))
plt.plot(a,b,'bo-')
for x,y in zip(a, b): 
    plt.text(x+0.5, y, str(round(y)))
#plt.title("f")
plt.show()
# Out:
# KR not in financials_clear financials_2001
# WBA not in financials_clear financials_2001
# LIN not in financials_clear financials_2001
# EFX not in financials_clear financials_2001
# FDX not in financials_clear financials_2001
# RF not in financials_clear financials_2001
# CA not in financials_clear financials_2001
# DD not in financials_clear financials_2001
# DOW not in financials_clear financials_2001
# BBBY not in financials_clear financials_2001
# CCEP not in financials_clear financials_2001
# DXC not in financials_clear financials_2001
# PLL not in financials_clear financials_2001
# AMCR not in financials_clear financials_2001
# DELL not in financials_clear financials_2001
# SUN not in financials_clear financials_2001
# NSM not in financials_clear financials_2001
# GM not in financials_clear financials_2001
# ABI not in financials_clear financials_2001
# BUD not in financials_clear financials_2001
# CCU not in financials_clear financials_2001
# CC not in financials_clear financials_2001
# TIN not in financials_clear financials_2001
# AT not in financials_clear financials_2001
# HLT not in financials_clear financials_2001
# FDC not in financials_clear financials_2001
# DG not in financials_clear financials_2001
# NAV not in financials_clear financials_2001
# HCA not in financials_clear financials_2001
# EC not in financials_clear financials_2001
# JP not in financials_clear financials_2001
# BR not in financials_clear financials_2001
# VIAC not in financials_clear financials_2001
# G not in financials_clear financials_2001
# DAL not in financials_clear financials_2001
# ONE not in financials_clear financials_2001
# AM not in financials_clear financials_2001
# HI not in financials_clear financials_2001
# HRC not in financials_clear financials_2001
# AMR not in financials_clear financials_2001
# TRW not in financials_clear financials_2001
# UN not in financials_clear financials_2001
# GOLD not in financials_clear financials_2001
# AL not in financials_clear financials_2001
# WLL not in financials_clear financials_2001
# MEA not in financials_clear financials_2001
# TKR not in financials_clear financials_2001
# H not in financials_clear financials_2001
# ADPT not in financials_clear financials_2001
# FSR not in financials_clear financials_2001
# CCK not in financials_clear financials_2001
# CG not in financials_clear financials_2001
# GTE not in financials_clear financials_2001
# SGI not in financials_clear financials_2001
# CHA not in financials_clear financials_2001
# CSR not in financials_clear financials_2001
# MIR not in financials_clear financials_2001
# RLM not in financials_clear financials_2001
# ARC not in financials_clear financials_2001
# SCI not in financials_clear financials_2001
# LIN not in financials_monthly_2001
# BKR not in financials_monthly_2001
# DOW not in financials_monthly_2001
# DXC not in financials_monthly_2001
# PLL not in financials_monthly_2001
# AMCR not in financials_monthly_2001
# BEAM not in financials_monthly_2001
# DELL not in financials_monthly_2001
# SUN not in financials_monthly_2001
# LXK not in financials_monthly_2001
# CEG not in financials_monthly_2001
# NSM not in financials_monthly_2001
# GM not in financials_monthly_2001
# ROH not in financials_monthly_2001
# MER not in financials_monthly_2001
# ABI not in financials_monthly_2001
# BUD not in financials_monthly_2001
# HPC not in financials_monthly_2001
# EDS not in financials_monthly_2001
# OMX not in financials_monthly_2001
# CC not in financials_monthly_2001
# TIN not in financials_monthly_2001
# AT not in financials_monthly_2001
# HCR not in financials_monthly_2001
# HLT not in financials_monthly_2001
# FDC not in financials_monthly_2001
# DG not in financials_monthly_2001
# ADCT not in financials_monthly_2001
# PD not in financials_monthly_2001
# LU not in financials_monthly_2001
# HCA not in financials_monthly_2001
# EC not in financials_monthly_2001
# JP not in financials_monthly_2001
# BR not in financials_monthly_2001
# VIAC not in financials_monthly_2001
# G not in financials_monthly_2001
# DAL not in financials_monthly_2001
# UCL not in financials_monthly_2001
# ONE not in financials_monthly_2001
# AM not in financials_monthly_2001
# HI not in financials_monthly_2001
# AMR not in financials_monthly_2001
# TRW not in financials_monthly_2001
# CNC not in financials_monthly_2001
# AL not in financials_monthly_2001
# U not in financials_monthly_2001
# WLL not in financials_monthly_2001
# MEA not in financials_monthly_2001
# H not in financials_monthly_2001
# ADPT not in financials_monthly_2001
# FSR not in financials_monthly_2001
# CG not in financials_monthly_2001
# COMS not in financials_monthly_2001
# GTE not in financials_monthly_2001
# IKN not in financials_monthly_2001
# SGI not in financials_monthly_2001
# CHA not in financials_monthly_2001
# MIR not in financials_monthly_2001
# RLM not in financials_monthly_2001
# ARC not in financials_monthly_2001
# LIN not in financials_clear financials_2002
# RF not in financials_clear financials_2002
# CA not in financials_clear financials_2002
# DD not in financials_clear financials_2002
# DOW not in financials_clear financials_2002
# CCEP not in financials_clear financials_2002
# DXC not in financials_clear financials_2002
# PLL not in financials_clear financials_2002
# AMCR not in financials_clear financials_2002
# DELL not in financials_clear financials_2002
# SUN not in financials_clear financials_2002
# NSM not in financials_clear financials_2002
# GM not in financials_clear financials_2002
# ABI not in financials_clear financials_2002
# BUD not in financials_clear financials_2002
# CC not in financials_clear financials_2002
# TIN not in financials_clear financials_2002
# AT not in financials_clear financials_2002
# HLT not in financials_clear financials_2002
# FDC not in financials_clear financials_2002
# DG not in financials_clear financials_2002
# NAV not in financials_clear financials_2002
# HCA not in financials_clear financials_2002
# EC not in financials_clear financials_2002
# JP not in financials_clear financials_2002
# BR not in financials_clear financials_2002
# VIAC not in financials_clear financials_2002
# G not in financials_clear financials_2002
# DAL not in financials_clear financials_2002
# ONE not in financials_clear financials_2002
# AM not in financials_clear financials_2002
# HI not in financials_clear financials_2002
# HRC not in financials_clear financials_2002
# AMR not in financials_clear financials_2002
# TRW not in financials_clear financials_2002
# UN not in financials_clear financials_2002
# AL not in financials_clear financials_2002
# WLL not in financials_clear financials_2002
# MEA not in financials_clear financials_2002
# TKR not in financials_clear financials_2002
# H not in financials_clear financials_2002
# ADPT not in financials_clear financials_2002
# FSR not in financials_clear financials_2002
# CG not in financials_clear financials_2002
# GTE not in financials_clear financials_2002
# SGI not in financials_clear financials_2002
# CSR not in financials_clear financials_2002
# MIR not in financials_clear financials_2002
# RLM not in financials_clear financials_2002
# ARC not in financials_clear financials_2002
# LIN not in financials_monthly_2002
# BKR not in financials_monthly_2002
# DOW not in financials_monthly_2002
# DXC not in financials_monthly_2002
# PLL not in financials_monthly_2002
# AMCR not in financials_monthly_2002
# BEAM not in financials_monthly_2002
# DELL not in financials_monthly_2002
# SUN not in financials_monthly_2002
# LXK not in financials_monthly_2002
# CEG not in financials_monthly_2002
# NSM not in financials_monthly_2002
# GM not in financials_monthly_2002
# ROH not in financials_monthly_2002
# MER not in financials_monthly_2002
# ABI not in financials_monthly_2002
# BUD not in financials_monthly_2002
# HPC not in financials_monthly_2002
# EDS not in financials_monthly_2002
# OMX not in financials_monthly_2002
# CC not in financials_monthly_2002
# TIN not in financials_monthly_2002
# AT not in financials_monthly_2002
# HCR not in financials_monthly_2002
# HLT not in financials_monthly_2002
# FDC not in financials_monthly_2002
# DG not in financials_monthly_2002
# ADCT not in financials_monthly_2002
# PD not in financials_monthly_2002
# LU not in financials_monthly_2002
# HCA not in financials_monthly_2002
# EC not in financials_monthly_2002
# JP not in financials_monthly_2002
# BR not in financials_monthly_2002
# VIAC not in financials_monthly_2002
# G not in financials_monthly_2002
# DAL not in financials_monthly_2002
# UCL not in financials_monthly_2002
# ONE not in financials_monthly_2002
# AM not in financials_monthly_2002
# HI not in financials_monthly_2002
# AMR not in financials_monthly_2002
# TRW not in financials_monthly_2002
# AL not in financials_monthly_2002
# U not in financials_monthly_2002
# WLL not in financials_monthly_2002
# MEA not in financials_monthly_2002
# H not in financials_monthly_2002
# ADPT not in financials_monthly_2002
# FSR not in financials_monthly_2002
# CG not in financials_monthly_2002
# COMS not in financials_monthly_2002
# GTE not in financials_monthly_2002
# IKN not in financials_monthly_2002
# SGI not in financials_monthly_2002
# MIR not in financials_monthly_2002
# RLM not in financials_monthly_2002
# ARC not in financials_monthly_2002
# LIN not in financials_clear financials_2003
# DD not in financials_clear financials_2003
# DOW not in financials_clear financials_2003
# CCEP not in financials_clear financials_2003
# DXC not in financials_clear financials_2003
# PLL not in financials_clear financials_2003
# AMCR not in financials_clear financials_2003
# DELL not in financials_clear financials_2003
# SUN not in financials_clear financials_2003
# NSM not in financials_clear financials_2003
# GM not in financials_clear financials_2003
# ABI not in financials_clear financials_2003
# BUD not in financials_clear financials_2003
# CC not in financials_clear financials_2003
# TIN not in financials_clear financials_2003
# AT not in financials_clear financials_2003
# HLT not in financials_clear financials_2003
# FDC not in financials_clear financials_2003
# DG not in financials_clear financials_2003
# NAV not in financials_clear financials_2003
# HCA not in financials_clear financials_2003
# EC not in financials_clear financials_2003
# JP not in financials_clear financials_2003
# BR not in financials_clear financials_2003
# G not in financials_clear financials_2003
# DAL not in financials_clear financials_2003
# ONE not in financials_clear financials_2003
# AM not in financials_clear financials_2003
# HI not in financials_clear financials_2003
# AMR not in financials_clear financials_2003
# TRW not in financials_clear financials_2003
# UN not in financials_clear financials_2003
# AL not in financials_clear financials_2003
# U not in financials_clear financials_2003
# MEA not in financials_clear financials_2003
# TKR not in financials_clear financials_2003
# H not in financials_clear financials_2003
# ADPT not in financials_clear financials_2003
# FSR not in financials_clear financials_2003
# CG not in financials_clear financials_2003
# GTE not in financials_clear financials_2003
# SGI not in financials_clear financials_2003
# CSR not in financials_clear financials_2003
# MIR not in financials_clear financials_2003
# RLM not in financials_clear financials_2003
# ARC not in financials_clear financials_2003
# LIN not in financials_monthly_2003
# BKR not in financials_monthly_2003
# DOW not in financials_monthly_2003
# DXC not in financials_monthly_2003
# PLL not in financials_monthly_2003
# AMCR not in financials_monthly_2003
# BEAM not in financials_monthly_2003
# DELL not in financials_monthly_2003
# SUN not in financials_monthly_2003
# LXK not in financials_monthly_2003
# CEG not in financials_monthly_2003
# NSM not in financials_monthly_2003
# GM not in financials_monthly_2003
# ROH not in financials_monthly_2003
# MER not in financials_monthly_2003
# ABI not in financials_monthly_2003
# BUD not in financials_monthly_2003
# HPC not in financials_monthly_2003
# EDS not in financials_monthly_2003
# OMX not in financials_monthly_2003
# CC not in financials_monthly_2003
# TIN not in financials_monthly_2003
# AT not in financials_monthly_2003
# HCR not in financials_monthly_2003
# HLT not in financials_monthly_2003
# FDC not in financials_monthly_2003
# DG not in financials_monthly_2003
# ADCT not in financials_monthly_2003
# PD not in financials_monthly_2003
# LU not in financials_monthly_2003
# HCA not in financials_monthly_2003
# EC not in financials_monthly_2003
# JP not in financials_monthly_2003
# BR not in financials_monthly_2003
# VIAC not in financials_monthly_2003
# G not in financials_monthly_2003
# DAL not in financials_monthly_2003
# UCL not in financials_monthly_2003
# ONE not in financials_monthly_2003
# AM not in financials_monthly_2003
# HI not in financials_monthly_2003
# AMR not in financials_monthly_2003
# TRW not in financials_monthly_2003
# AL not in financials_monthly_2003
# U not in financials_monthly_2003
# WLL not in financials_monthly_2003
# MEA not in financials_monthly_2003
# H not in financials_monthly_2003
# ADPT not in financials_monthly_2003
# FSR not in financials_monthly_2003
# CG not in financials_monthly_2003
# COMS not in financials_monthly_2003
# GTE not in financials_monthly_2003
# IKN not in financials_monthly_2003
# SGI not in financials_monthly_2003
# MIR not in financials_monthly_2003
# RLM not in financials_monthly_2003
# ARC not in financials_monthly_2003
# IPG not in financials_clear financials_2004
# LIN not in financials_clear financials_2004
# DD not in financials_clear financials_2004
# DOW not in financials_clear financials_2004
# CCEP not in financials_clear financials_2004
# DXC not in financials_clear financials_2004
# PLL not in financials_clear financials_2004
# AMCR not in financials_clear financials_2004
# DELL not in financials_clear financials_2004
# SUN not in financials_clear financials_2004
# NSM not in financials_clear financials_2004
# GM not in financials_clear financials_2004
# ABI not in financials_clear financials_2004
# BUD not in financials_clear financials_2004
# CC not in financials_clear financials_2004
# AT not in financials_clear financials_2004
# HLT not in financials_clear financials_2004
# FDC not in financials_clear financials_2004
# DG not in financials_clear financials_2004
# NAV not in financials_clear financials_2004
# HCA not in financials_clear financials_2004
# EC not in financials_clear financials_2004
# JP not in financials_clear financials_2004
# BR not in financials_clear financials_2004
# G not in financials_clear financials_2004
# DAL not in financials_clear financials_2004
# ONE not in financials_clear financials_2004
# AM not in financials_clear financials_2004
# HI not in financials_clear financials_2004
# AMR not in financials_clear financials_2004
# UN not in financials_clear financials_2004
# AL not in financials_clear financials_2004
# U not in financials_clear financials_2004
# TKR not in financials_clear financials_2004
# H not in financials_clear financials_2004
# ADPT not in financials_clear financials_2004
# FSR not in financials_clear financials_2004
# CG not in financials_clear financials_2004
# GTE not in financials_clear financials_2004
# SGI not in financials_clear financials_2004
# CSR not in financials_clear financials_2004
# MIR not in financials_clear financials_2004
# RLM not in financials_clear financials_2004
# LIN not in financials_monthly_2004
# BKR not in financials_monthly_2004
# DOW not in financials_monthly_2004
# DXC not in financials_monthly_2004
# PLL not in financials_monthly_2004
# AMCR not in financials_monthly_2004
# BEAM not in financials_monthly_2004
# DELL not in financials_monthly_2004
# SUN not in financials_monthly_2004
# LXK not in financials_monthly_2004
# CEG not in financials_monthly_2004
# NSM not in financials_monthly_2004
# GM not in financials_monthly_2004
# ROH not in financials_monthly_2004
# MER not in financials_monthly_2004
# ABI not in financials_monthly_2004
# BUD not in financials_monthly_2004
# HPC not in financials_monthly_2004
# EDS not in financials_monthly_2004
# OMX not in financials_monthly_2004
# CC not in financials_monthly_2004
# TIN not in financials_monthly_2004
# AT not in financials_monthly_2004
# HCR not in financials_monthly_2004
# HLT not in financials_monthly_2004
# FDC not in financials_monthly_2004
# DG not in financials_monthly_2004
# ADCT not in financials_monthly_2004
# PD not in financials_monthly_2004
# LU not in financials_monthly_2004
# HCA not in financials_monthly_2004
# EC not in financials_monthly_2004
# JP not in financials_monthly_2004
# BR not in financials_monthly_2004
# VIAC not in financials_monthly_2004
# G not in financials_monthly_2004
# DAL not in financials_monthly_2004
# UCL not in financials_monthly_2004
# ONE not in financials_monthly_2004
# AM not in financials_monthly_2004
# HI not in financials_monthly_2004
# AMR not in financials_monthly_2004
# AL not in financials_monthly_2004
# U not in financials_monthly_2004
# WLL not in financials_monthly_2004
# MEA not in financials_monthly_2004
# H not in financials_monthly_2004
# ADPT not in financials_monthly_2004
# FSR not in financials_monthly_2004
# CG not in financials_monthly_2004
# COMS not in financials_monthly_2004
# GTE not in financials_monthly_2004
# IKN not in financials_monthly_2004
# SGI not in financials_monthly_2004
# MIR not in financials_monthly_2004
# RLM not in financials_monthly_2004
# ARC not in financials_monthly_2004
# LIN not in financials_clear financials_2005
# BKR not in financials_clear financials_2005
# DD not in financials_clear financials_2005
# DOW not in financials_clear financials_2005
# CCEP not in financials_clear financials_2005
# DXC not in financials_clear financials_2005
# PLL not in financials_clear financials_2005
# AMCR not in financials_clear financials_2005
# DELL not in financials_clear financials_2005
# SUN not in financials_clear financials_2005
# NSM not in financials_clear financials_2005
# GM not in financials_clear financials_2005
# ABI not in financials_clear financials_2005
# BUD not in financials_clear financials_2005
# CC not in financials_clear financials_2005
# AT not in financials_clear financials_2005
# HLT not in financials_clear financials_2005
# FDC not in financials_clear financials_2005
# DG not in financials_clear financials_2005
# HCA not in financials_clear financials_2005
# EC not in financials_clear financials_2005
# JP not in financials_clear financials_2005
# BR not in financials_clear financials_2005
# G not in financials_clear financials_2005
# DAL not in financials_clear financials_2005
# UCL not in financials_clear financials_2005
# ONE not in financials_clear financials_2005
# AM not in financials_clear financials_2005
# HI not in financials_clear financials_2005
# AMR not in financials_clear financials_2005
# UN not in financials_clear financials_2005
# AL not in financials_clear financials_2005
# U not in financials_clear financials_2005
# H not in financials_clear financials_2005
# ADPT not in financials_clear financials_2005
# FSR not in financials_clear financials_2005
# CG not in financials_clear financials_2005
# CSR not in financials_clear financials_2005
# RLM not in financials_clear financials_2005
# LIN not in financials_monthly_2005
# BKR not in financials_monthly_2005
# DOW not in financials_monthly_2005
# DXC not in financials_monthly_2005
# PLL not in financials_monthly_2005
# AMCR not in financials_monthly_2005
# BEAM not in financials_monthly_2005
# DELL not in financials_monthly_2005
# SUN not in financials_monthly_2005
# LXK not in financials_monthly_2005
# CEG not in financials_monthly_2005
# NSM not in financials_monthly_2005
# GM not in financials_monthly_2005
# ROH not in financials_monthly_2005
# MER not in financials_monthly_2005
# ABI not in financials_monthly_2005
# BUD not in financials_monthly_2005
# HPC not in financials_monthly_2005
# EDS not in financials_monthly_2005
# OMX not in financials_monthly_2005
# CC not in financials_monthly_2005
# TIN not in financials_monthly_2005
# AT not in financials_monthly_2005
# HCR not in financials_monthly_2005
# HLT not in financials_monthly_2005
# FDC not in financials_monthly_2005
# DG not in financials_monthly_2005
# ADCT not in financials_monthly_2005
# PD not in financials_monthly_2005
# LU not in financials_monthly_2005
# HCA not in financials_monthly_2005
# EC not in financials_monthly_2005
# JP not in financials_monthly_2005
# BR not in financials_monthly_2005
# VIAC not in financials_monthly_2005
# G not in financials_monthly_2005
# DAL not in financials_monthly_2005
# UCL not in financials_monthly_2005
# ONE not in financials_monthly_2005
# AM not in financials_monthly_2005
# HI not in financials_monthly_2005
# AMR not in financials_monthly_2005
# AL not in financials_monthly_2005
# U not in financials_monthly_2005
# WLL not in financials_monthly_2005
# H not in financials_monthly_2005
# ADPT not in financials_monthly_2005
# FSR not in financials_monthly_2005
# CG not in financials_monthly_2005
# COMS not in financials_monthly_2005
# GTE not in financials_monthly_2005
# IKN not in financials_monthly_2005
# SGI not in financials_monthly_2005
# MIR not in financials_monthly_2005
# RLM not in financials_monthly_2005
# KLAC not in financials_clear financials_2006
# LIN not in financials_clear financials_2006
# CTXS not in financials_clear financials_2006
# DD not in financials_clear financials_2006
# DOW not in financials_clear financials_2006
# CCEP not in financials_clear financials_2006
# DXC not in financials_clear financials_2006
# PLL not in financials_clear financials_2006
# AMCR not in financials_clear financials_2006
# DELL not in financials_clear financials_2006
# SUN not in financials_clear financials_2006
# NSM not in financials_clear financials_2006
# GM not in financials_clear financials_2006
# ABI not in financials_clear financials_2006
# BUD not in financials_clear financials_2006
# CC not in financials_clear financials_2006
# AT not in financials_clear financials_2006
# HLT not in financials_clear financials_2006
# FDC not in financials_clear financials_2006
# DG not in financials_clear financials_2006
# NAV not in financials_clear financials_2006
# LU not in financials_clear financials_2006
# HCA not in financials_clear financials_2006
# EC not in financials_clear financials_2006
# JP not in financials_clear financials_2006
# BR not in financials_clear financials_2006
# G not in financials_clear financials_2006
# DAL not in financials_clear financials_2006
# UCL not in financials_clear financials_2006
# ONE not in financials_clear financials_2006
# AM not in financials_clear financials_2006
# HI not in financials_clear financials_2006
# AMR not in financials_clear financials_2006
# UN not in financials_clear financials_2006
# AL not in financials_clear financials_2006
# U not in financials_clear financials_2006
# H not in financials_clear financials_2006
# ADPT not in financials_clear financials_2006
# FSR not in financials_clear financials_2006
# CG not in financials_clear financials_2006
# CSR not in financials_clear financials_2006
# RLM not in financials_clear financials_2006
# LIN not in financials_monthly_2006
# BKR not in financials_monthly_2006
# DOW not in financials_monthly_2006
# DXC not in financials_monthly_2006
# PLL not in financials_monthly_2006
# AMCR not in financials_monthly_2006
# BEAM not in financials_monthly_2006
# DELL not in financials_monthly_2006
# SUN not in financials_monthly_2006
# LXK not in financials_monthly_2006
# CEG not in financials_monthly_2006
# NSM not in financials_monthly_2006
# GM not in financials_monthly_2006
# ROH not in financials_monthly_2006
# MER not in financials_monthly_2006
# ABI not in financials_monthly_2006
# BUD not in financials_monthly_2006
# HPC not in financials_monthly_2006
# EDS not in financials_monthly_2006
# OMX not in financials_monthly_2006
# CC not in financials_monthly_2006
# TIN not in financials_monthly_2006
# AT not in financials_monthly_2006
# HCR not in financials_monthly_2006
# HLT not in financials_monthly_2006
# FDC not in financials_monthly_2006
# DG not in financials_monthly_2006
# ADCT not in financials_monthly_2006
# PD not in financials_monthly_2006
# LU not in financials_monthly_2006
# HCA not in financials_monthly_2006
# EC not in financials_monthly_2006
# JP not in financials_monthly_2006
# BR not in financials_monthly_2006
# G not in financials_monthly_2006
# DAL not in financials_monthly_2006
# UCL not in financials_monthly_2006
# ONE not in financials_monthly_2006
# AM not in financials_monthly_2006
# HI not in financials_monthly_2006
# AMR not in financials_monthly_2006
# AL not in financials_monthly_2006
# U not in financials_monthly_2006
# WLL not in financials_monthly_2006
# H not in financials_monthly_2006
# ADPT not in financials_monthly_2006
# FSR not in financials_monthly_2006
# CG not in financials_monthly_2006
# COMS not in financials_monthly_2006
# IKN not in financials_monthly_2006
# SGI not in financials_monthly_2006
# MIR not in financials_monthly_2006
# RLM not in financials_monthly_2006
# LIN not in financials_clear financials_2007
# DD not in financials_clear financials_2007
# DOW not in financials_clear financials_2007
# CCEP not in financials_clear financials_2007
# DXC not in financials_clear financials_2007
# PLL not in financials_clear financials_2007
# AMCR not in financials_clear financials_2007
# DELL not in financials_clear financials_2007
# SUN not in financials_clear financials_2007
# NSM not in financials_clear financials_2007
# GM not in financials_clear financials_2007
# ABI not in financials_clear financials_2007
# BUD not in financials_clear financials_2007
# CC not in financials_clear financials_2007
# AT not in financials_clear financials_2007
# HCR not in financials_clear financials_2007
# HLT not in financials_clear financials_2007
# FDC not in financials_clear financials_2007
# DG not in financials_clear financials_2007
# PD not in financials_clear financials_2007
# LU not in financials_clear financials_2007
# HCA not in financials_clear financials_2007
# EC not in financials_clear financials_2007
# JP not in financials_clear financials_2007
# DAL not in financials_clear financials_2007
# UCL not in financials_clear financials_2007
# ONE not in financials_clear financials_2007
# AM not in financials_clear financials_2007
# HI not in financials_clear financials_2007
# AMR not in financials_clear financials_2007
# UN not in financials_clear financials_2007
# AL not in financials_clear financials_2007
# U not in financials_clear financials_2007
# H not in financials_clear financials_2007
# ADPT not in financials_clear financials_2007
# CG not in financials_clear financials_2007
# RLM not in financials_clear financials_2007
# LIN not in financials_monthly_2007
# BKR not in financials_monthly_2007
# DOW not in financials_monthly_2007
# DXC not in financials_monthly_2007
# PLL not in financials_monthly_2007
# AMCR not in financials_monthly_2007
# BEAM not in financials_monthly_2007
# DELL not in financials_monthly_2007
# SUN not in financials_monthly_2007
# LXK not in financials_monthly_2007
# NSM not in financials_monthly_2007
# GM not in financials_monthly_2007
# ABI not in financials_monthly_2007
# BUD not in financials_monthly_2007
# EDS not in financials_monthly_2007
# CC not in financials_monthly_2007
# TIN not in financials_monthly_2007
# AT not in financials_monthly_2007
# HCR not in financials_monthly_2007
# HLT not in financials_monthly_2007
# FDC not in financials_monthly_2007
# DG not in financials_monthly_2007
# ADCT not in financials_monthly_2007
# PD not in financials_monthly_2007
# LU not in financials_monthly_2007
# HCA not in financials_monthly_2007
# EC not in financials_monthly_2007
# JP not in financials_monthly_2007
# UCL not in financials_monthly_2007
# ONE not in financials_monthly_2007
# AM not in financials_monthly_2007
# HI not in financials_monthly_2007
# AMR not in financials_monthly_2007
# AL not in financials_monthly_2007
# U not in financials_monthly_2007
# WLL not in financials_monthly_2007
# H not in financials_monthly_2007
# ADPT not in financials_monthly_2007
# FSR not in financials_monthly_2007
# CG not in financials_monthly_2007
# COMS not in financials_monthly_2007
# SGI not in financials_monthly_2007
# RLM not in financials_monthly_2007
# LIN not in financials_clear financials_2008
# DOW not in financials_clear financials_2008
# CCEP not in financials_clear financials_2008
# DXC not in financials_clear financials_2008
# PLL not in financials_clear financials_2008
# AMCR not in financials_clear financials_2008
# DELL not in financials_clear financials_2008
# SUN not in financials_clear financials_2008
# NSM not in financials_clear financials_2008
# GM not in financials_clear financials_2008
# MER not in financials_clear financials_2008
# ABI not in financials_clear financials_2008
# BUD not in financials_clear financials_2008
# HPC not in financials_clear financials_2008
# EDS not in financials_clear financials_2008
# CC not in financials_clear financials_2008
# AT not in financials_clear financials_2008
# HCR not in financials_clear financials_2008
# HLT not in financials_clear financials_2008
# FDC not in financials_clear financials_2008
# DG not in financials_clear financials_2008
# PD not in financials_clear financials_2008
# LU not in financials_clear financials_2008
# HCA not in financials_clear financials_2008
# JP not in financials_clear financials_2008
# UCL not in financials_clear financials_2008
# ONE not in financials_clear financials_2008
# AM not in financials_clear financials_2008
# AMR not in financials_clear financials_2008
# UN not in financials_clear financials_2008
# AL not in financials_clear financials_2008
# U not in financials_clear financials_2008
# H not in financials_clear financials_2008
# ADPT not in financials_clear financials_2008
# CG not in financials_clear financials_2008
# IKN not in financials_clear financials_2008
# RLM not in financials_clear financials_2008
# LIN not in financials_monthly_2008
# BKR not in financials_monthly_2008
# DOW not in financials_monthly_2008
# DXC not in financials_monthly_2008
# PLL not in financials_monthly_2008
# AMCR not in financials_monthly_2008
# BEAM not in financials_monthly_2008
# DELL not in financials_monthly_2008
# SUN not in financials_monthly_2008
# LXK not in financials_monthly_2008
# NSM not in financials_monthly_2008
# GM not in financials_monthly_2008
# ABI not in financials_monthly_2008
# BUD not in financials_monthly_2008
# CC not in financials_monthly_2008
# TIN not in financials_monthly_2008
# AT not in financials_monthly_2008
# HCR not in financials_monthly_2008
# HLT not in financials_monthly_2008
# FDC not in financials_monthly_2008
# DG not in financials_monthly_2008
# ADCT not in financials_monthly_2008
# PD not in financials_monthly_2008
# LU not in financials_monthly_2008
# HCA not in financials_monthly_2008
# JP not in financials_monthly_2008
# UCL not in financials_monthly_2008
# ONE not in financials_monthly_2008
# AM not in financials_monthly_2008
# AMR not in financials_monthly_2008
# AL not in financials_monthly_2008
# U not in financials_monthly_2008
# WLL not in financials_monthly_2008
# H not in financials_monthly_2008
# ADPT not in financials_monthly_2008
# FSR not in financials_monthly_2008
# CG not in financials_monthly_2008
# COMS not in financials_monthly_2008
# SGI not in financials_monthly_2008
# RLM not in financials_monthly_2008
# MER not in financials_monthly_2009
# HPC not in financials_monthly_2009
# IKN not in financials_monthly_2009
# LIN not in financials_clear financials_2009
# DOW not in financials_clear financials_2009
# CCEP not in financials_clear financials_2009
# DXC not in financials_clear financials_2009
# PLL not in financials_clear financials_2009
# AMCR not in financials_clear financials_2009
# DELL not in financials_clear financials_2009
# SUN not in financials_clear financials_2009
# NSM not in financials_clear financials_2009
# GM not in financials_clear financials_2009
# ROH not in financials_clear financials_2009
# MER not in financials_clear financials_2009
# ABI not in financials_clear financials_2009
# HPC not in financials_clear financials_2009
# EDS not in financials_clear financials_2009
# CC not in financials_clear financials_2009
# AT not in financials_clear financials_2009
# HCR not in financials_clear financials_2009
# HLT not in financials_clear financials_2009
# FDC not in financials_clear financials_2009
# PD not in financials_clear financials_2009
# LU not in financials_clear financials_2009
# HCA not in financials_clear financials_2009
# JP not in financials_clear financials_2009
# UCL not in financials_clear financials_2009
# ONE not in financials_clear financials_2009
# AM not in financials_clear financials_2009
# AMR not in financials_clear financials_2009
# UN not in financials_clear financials_2009
# AL not in financials_clear financials_2009
# U not in financials_clear financials_2009
# ADPT not in financials_clear financials_2009
# CG not in financials_clear financials_2009
# IKN not in financials_clear financials_2009
# SGI not in financials_clear financials_2009
# RLM not in financials_clear financials_2009
# LIN not in financials_monthly_2009
# BKR not in financials_monthly_2009
# DOW not in financials_monthly_2009
# DXC not in financials_monthly_2009
# PLL not in financials_monthly_2009
# AMCR not in financials_monthly_2009
# BEAM not in financials_monthly_2009
# DELL not in financials_monthly_2009
# SUN not in financials_monthly_2009
# LXK not in financials_monthly_2009
# NSM not in financials_monthly_2009
# GM not in financials_monthly_2009
# MER not in financials_monthly_2009
# HPC not in financials_monthly_2009
# CC not in financials_monthly_2009
# TIN not in financials_monthly_2009
# AT not in financials_monthly_2009
# HCR not in financials_monthly_2009
# HLT not in financials_monthly_2009
# FDC not in financials_monthly_2009
# ADCT not in financials_monthly_2009
# PD not in financials_monthly_2009
# LU not in financials_monthly_2009
# HCA not in financials_monthly_2009
# JP not in financials_monthly_2009
# UCL not in financials_monthly_2009
# ONE not in financials_monthly_2009
# AM not in financials_monthly_2009
# AMR not in financials_monthly_2009
# AL not in financials_monthly_2009
# U not in financials_monthly_2009
# WLL not in financials_monthly_2009
# ADPT not in financials_monthly_2009
# FSR not in financials_monthly_2009
# CG not in financials_monthly_2009
# COMS not in financials_monthly_2009
# IKN not in financials_monthly_2009
# RLM not in financials_monthly_2009
# ROH not in financials_monthly_2010
# LIN not in financials_clear financials_2010
# DOW not in financials_clear financials_2010
# CCEP not in financials_clear financials_2010
# DXC not in financials_clear financials_2010
# PLL not in financials_clear financials_2010
# AMCR not in financials_clear financials_2010
# DELL not in financials_clear financials_2010
# SUN not in financials_clear financials_2010
# NSM not in financials_clear financials_2010
# ROH not in financials_clear financials_2010
# MER not in financials_clear financials_2010
# ABI not in financials_clear financials_2010
# HPC not in financials_clear financials_2010
# EDS not in financials_clear financials_2010
# CC not in financials_clear financials_2010
# HCR not in financials_clear financials_2010
# HLT not in financials_clear financials_2010
# FDC not in financials_clear financials_2010
# PD not in financials_clear financials_2010
# LU not in financials_clear financials_2010
# HCA not in financials_clear financials_2010
# JP not in financials_clear financials_2010
# UCL not in financials_clear financials_2010
# ONE not in financials_clear financials_2010
# AM not in financials_clear financials_2010
# AMR not in financials_clear financials_2010
# UN not in financials_clear financials_2010
# AL not in financials_clear financials_2010
# U not in financials_clear financials_2010
# ADPT not in financials_clear financials_2010
# CG not in financials_clear financials_2010
# COMS not in financials_clear financials_2010
# IKN not in financials_clear financials_2010
# MIR not in financials_clear financials_2010
# RLM not in financials_clear financials_2010
# LIN not in financials_monthly_2010
# BKR not in financials_monthly_2010
# DOW not in financials_monthly_2010
# DXC not in financials_monthly_2010
# PLL not in financials_monthly_2010
# AMCR not in financials_monthly_2010
# BEAM not in financials_monthly_2010
# DELL not in financials_monthly_2010
# SUN not in financials_monthly_2010
# LXK not in financials_monthly_2010
# NSM not in financials_monthly_2010
# ROH not in financials_monthly_2010
# MER not in financials_monthly_2010
# HPC not in financials_monthly_2010
# CC not in financials_monthly_2010
# TIN not in financials_monthly_2010
# HCR not in financials_monthly_2010
# HLT not in financials_monthly_2010
# FDC not in financials_monthly_2010
# ADCT not in financials_monthly_2010
# PD not in financials_monthly_2010
# LU not in financials_monthly_2010
# HCA not in financials_monthly_2010
# JP not in financials_monthly_2010
# UCL not in financials_monthly_2010
# ONE not in financials_monthly_2010
# AM not in financials_monthly_2010
# AMR not in financials_monthly_2010
# AL not in financials_monthly_2010
# U not in financials_monthly_2010
# WLL not in financials_monthly_2010
# ADPT not in financials_monthly_2010
# FSR not in financials_monthly_2010
# CG not in financials_monthly_2010
# COMS not in financials_monthly_2010
# IKN not in financials_monthly_2010
# RLM not in financials_monthly_2010
# MIR not in financials_monthly_2011
# LIN not in financials_clear financials_2011
# DOW not in financials_clear financials_2011
# CCEP not in financials_clear financials_2011
# DXC not in financials_clear financials_2011
# PLL not in financials_clear financials_2011
# AMCR not in financials_clear financials_2011
# DELL not in financials_clear financials_2011
# SUN not in financials_clear financials_2011
# NSM not in financials_clear financials_2011
# ROH not in financials_clear financials_2011
# MER not in financials_clear financials_2011
# ABI not in financials_clear financials_2011
# HPC not in financials_clear financials_2011
# EDS not in financials_clear financials_2011
# CC not in financials_clear financials_2011
# TIN not in financials_clear financials_2011
# HCR not in financials_clear financials_2011
# HLT not in financials_clear financials_2011
# FDC not in financials_clear financials_2011
# ADCT not in financials_clear financials_2011
# PD not in financials_clear financials_2011
# LU not in financials_clear financials_2011
# JP not in financials_clear financials_2011
# UCL not in financials_clear financials_2011
# ONE not in financials_clear financials_2011
# AM not in financials_clear financials_2011
# AMR not in financials_clear financials_2011
# UN not in financials_clear financials_2011
# U not in financials_clear financials_2011
# ADPT not in financials_clear financials_2011
# CG not in financials_clear financials_2011
# COMS not in financials_clear financials_2011
# IKN not in financials_clear financials_2011
# CSR not in financials_clear financials_2011
# MIR not in financials_clear financials_2011
# RLM not in financials_clear financials_2011
# LIN not in financials_monthly_2011
# BKR not in financials_monthly_2011
# DOW not in financials_monthly_2011
# DXC not in financials_monthly_2011
# PLL not in financials_monthly_2011
# AMCR not in financials_monthly_2011
# BEAM not in financials_monthly_2011
# DELL not in financials_monthly_2011
# SUN not in financials_monthly_2011
# LXK not in financials_monthly_2011
# NSM not in financials_monthly_2011
# ROH not in financials_monthly_2011
# MER not in financials_monthly_2011
# HPC not in financials_monthly_2011
# CC not in financials_monthly_2011
# TIN not in financials_monthly_2011
# HCR not in financials_monthly_2011
# HLT not in financials_monthly_2011
# FDC not in financials_monthly_2011
# ADCT not in financials_monthly_2011
# PD not in financials_monthly_2011
# LU not in financials_monthly_2011
# JP not in financials_monthly_2011
# UCL not in financials_monthly_2011
# ONE not in financials_monthly_2011
# AM not in financials_monthly_2011
# AMR not in financials_monthly_2011
# U not in financials_monthly_2011
# WLL not in financials_monthly_2011
# ADPT not in financials_monthly_2011
# FSR not in financials_monthly_2011
# CG not in financials_monthly_2011
# COMS not in financials_monthly_2011
# IKN not in financials_monthly_2011
# MIR not in financials_monthly_2011
# RLM not in financials_monthly_2011
# LIN not in financials_clear financials_2012
# DOW not in financials_clear financials_2012
# CCEP not in financials_clear financials_2012
# DXC not in financials_clear financials_2012
# PLL not in financials_clear financials_2012
# AMCR not in financials_clear financials_2012
# DELL not in financials_clear financials_2012
# CEG not in financials_clear financials_2012
# ROH not in financials_clear financials_2012
# MER not in financials_clear financials_2012
# ABI not in financials_clear financials_2012
# HPC not in financials_clear financials_2012
# EDS not in financials_clear financials_2012
# CC not in financials_clear financials_2012
# TIN not in financials_clear financials_2012
# HCR not in financials_clear financials_2012
# HLT not in financials_clear financials_2012
# FDC not in financials_clear financials_2012
# ADCT not in financials_clear financials_2012
# PD not in financials_clear financials_2012
# LU not in financials_clear financials_2012
# JP not in financials_clear financials_2012
# UCL not in financials_clear financials_2012
# ONE not in financials_clear financials_2012
# AM not in financials_clear financials_2012
# AMR not in financials_clear financials_2012
# UN not in financials_clear financials_2012
# U not in financials_clear financials_2012
# ADPT not in financials_clear financials_2012
# FSR not in financials_clear financials_2012
# COMS not in financials_clear financials_2012
# IKN not in financials_clear financials_2012
# CSR not in financials_clear financials_2012
# MIR not in financials_clear financials_2012
# RLM not in financials_clear financials_2012
# LIN not in financials_monthly_2012
# BKR not in financials_monthly_2012
# DOW not in financials_monthly_2012
# DXC not in financials_monthly_2012
# PLL not in financials_monthly_2012
# AMCR not in financials_monthly_2012
# BEAM not in financials_monthly_2012
# DELL not in financials_monthly_2012
# LXK not in financials_monthly_2012
# ROH not in financials_monthly_2012
# MER not in financials_monthly_2012
# HPC not in financials_monthly_2012
# CC not in financials_monthly_2012
# TIN not in financials_monthly_2012
# HCR not in financials_monthly_2012
# HLT not in financials_monthly_2012
# FDC not in financials_monthly_2012
# ADCT not in financials_monthly_2012
# PD not in financials_monthly_2012
# LU not in financials_monthly_2012
# JP not in financials_monthly_2012
# UCL not in financials_monthly_2012
# ONE not in financials_monthly_2012
# AM not in financials_monthly_2012
# AMR not in financials_monthly_2012
# U not in financials_monthly_2012
# WLL not in financials_monthly_2012
# ADPT not in financials_monthly_2012
# FSR not in financials_monthly_2012
# COMS not in financials_monthly_2012
# IKN not in financials_monthly_2012
# MIR not in financials_monthly_2012
# RLM not in financials_monthly_2012
# LIN not in financials_clear financials_2013
# BKR not in financials_clear financials_2013
# DOW not in financials_clear financials_2013
# CCEP not in financials_clear financials_2013
# DXC not in financials_clear financials_2013
# PLL not in financials_clear financials_2013
# AMCR not in financials_clear financials_2013
# DELL not in financials_clear financials_2013
# HNZ not in financials_clear financials_2013
# CEG not in financials_clear financials_2013
# ROH not in financials_clear financials_2013
# MER not in financials_clear financials_2013
# ABI not in financials_clear financials_2013
# HPC not in financials_clear financials_2013
# EDS not in financials_clear financials_2013
# OMX not in financials_clear financials_2013
# CC not in financials_clear financials_2013
# TIN not in financials_clear financials_2013
# FDC not in financials_clear financials_2013
# ADCT not in financials_clear financials_2013
# PD not in financials_clear financials_2013
# LU not in financials_clear financials_2013
# JP not in financials_clear financials_2013
# UCL not in financials_clear financials_2013
# ONE not in financials_clear financials_2013
# AM not in financials_clear financials_2013
# AMR not in financials_clear financials_2013
# UN not in financials_clear financials_2013
# U not in financials_clear financials_2013
# ADPT not in financials_clear financials_2013
# FSR not in financials_clear financials_2013
# COMS not in financials_clear financials_2013
# IKN not in financials_clear financials_2013
# CSR not in financials_clear financials_2013
# MIR not in financials_clear financials_2013
# RLM not in financials_clear financials_2013
# LIN not in financials_monthly_2013
# BKR not in financials_monthly_2013
# DOW not in financials_monthly_2013
# DXC not in financials_monthly_2013
# PLL not in financials_monthly_2013
# AMCR not in financials_monthly_2013
# BEAM not in financials_monthly_2013
# DELL not in financials_monthly_2013
# LXK not in financials_monthly_2013
# ROH not in financials_monthly_2013
# MER not in financials_monthly_2013
# HPC not in financials_monthly_2013
# CC not in financials_monthly_2013
# TIN not in financials_monthly_2013
# HCR not in financials_monthly_2013
# HLT not in financials_monthly_2013
# FDC not in financials_monthly_2013
# ADCT not in financials_monthly_2013
# PD not in financials_monthly_2013
# LU not in financials_monthly_2013
# JP not in financials_monthly_2013
# UCL not in financials_monthly_2013
# ONE not in financials_monthly_2013
# AM not in financials_monthly_2013
# AMR not in financials_monthly_2013
# U not in financials_monthly_2013
# WLL not in financials_monthly_2013
# ADPT not in financials_monthly_2013
# FSR not in financials_monthly_2013
# COMS not in financials_monthly_2013
# IKN not in financials_monthly_2013
# MIR not in financials_monthly_2013
# RLM not in financials_monthly_2013
# HNZ not in financials_monthly_2014
# CEG not in financials_monthly_2014
# OMX not in financials_monthly_2014
# LIN not in financials_clear financials_2014
# BKR not in financials_clear financials_2014
# DOW not in financials_clear financials_2014
# CCEP not in financials_clear financials_2014
# DXC not in financials_clear financials_2014
# PLL not in financials_clear financials_2014
# SWY not in financials_clear financials_2014
# AMCR not in financials_clear financials_2014
# BEAM not in financials_clear financials_2014
# DELL not in financials_clear financials_2014
# HNZ not in financials_clear financials_2014
# SUN not in financials_clear financials_2014
# CEG not in financials_clear financials_2014
# RSH not in financials_clear financials_2014
# ROH not in financials_clear financials_2014
# MER not in financials_clear financials_2014
# ABI not in financials_clear financials_2014
# HPC not in financials_clear financials_2014
# EDS not in financials_clear financials_2014
# OMX not in financials_clear financials_2014
# CC not in financials_clear financials_2014
# TIN not in financials_clear financials_2014
# FDC not in financials_clear financials_2014
# ADCT not in financials_clear financials_2014
# PD not in financials_clear financials_2014
# LU not in financials_clear financials_2014
# JP not in financials_clear financials_2014
# UCL not in financials_clear financials_2014
# ONE not in financials_clear financials_2014
# AMR not in financials_clear financials_2014
# UN not in financials_clear financials_2014
# U not in financials_clear financials_2014
# FSR not in financials_clear financials_2014
# COMS not in financials_clear financials_2014
# IKN not in financials_clear financials_2014
# CSR not in financials_clear financials_2014
# MIR not in financials_clear financials_2014
# RLM not in financials_clear financials_2014
# LIN not in financials_monthly_2014
# BKR not in financials_monthly_2014
# DOW not in financials_monthly_2014
# DXC not in financials_monthly_2014
# PLL not in financials_monthly_2014
# AMCR not in financials_monthly_2014
# BEAM not in financials_monthly_2014
# DELL not in financials_monthly_2014
# HNZ not in financials_monthly_2014
# LXK not in financials_monthly_2014
# CEG not in financials_monthly_2014
# ROH not in financials_monthly_2014
# MER not in financials_monthly_2014
# HPC not in financials_monthly_2014
# OMX not in financials_monthly_2014
# CC not in financials_monthly_2014
# TIN not in financials_monthly_2014
# HCR not in financials_monthly_2014
# FDC not in financials_monthly_2014
# ADCT not in financials_monthly_2014
# PD not in financials_monthly_2014
# LU not in financials_monthly_2014
# JP not in financials_monthly_2014
# UCL not in financials_monthly_2014
# ONE not in financials_monthly_2014
# AMR not in financials_monthly_2014
# U not in financials_monthly_2014
# WLL not in financials_monthly_2014
# ADPT not in financials_monthly_2014
# FSR not in financials_monthly_2014
# COMS not in financials_monthly_2014
# IKN not in financials_monthly_2014
# MIR not in financials_monthly_2014
# RLM not in financials_monthly_2014
# HSH not in financials_monthly_2015
# ABI not in financials_monthly_2015
# LIN not in financials_clear financials_2015
# BKR not in financials_clear financials_2015
# DOW not in financials_clear financials_2015
# CCEP not in financials_clear financials_2015
# DXC not in financials_clear financials_2015
# SIAL not in financials_clear financials_2015
# PLL not in financials_clear financials_2015
# SWY not in financials_clear financials_2015
# AMCR not in financials_clear financials_2015
# BEAM not in financials_clear financials_2015
# DELL not in financials_clear financials_2015
# HNZ not in financials_clear financials_2015
# HSH not in financials_clear financials_2015
# CEG not in financials_clear financials_2015
# RSH not in financials_clear financials_2015
# ROH not in financials_clear financials_2015
# MER not in financials_clear financials_2015
# ABI not in financials_clear financials_2015
# HPC not in financials_clear financials_2015
# EDS not in financials_clear financials_2015
# OMX not in financials_clear financials_2015
# TIN not in financials_clear financials_2015
# ADCT not in financials_clear financials_2015
# PD not in financials_clear financials_2015
# LU not in financials_clear financials_2015
# JP not in financials_clear financials_2015
# UCL not in financials_clear financials_2015
# ONE not in financials_clear financials_2015
# AMR not in financials_clear financials_2015
# TRW not in financials_clear financials_2015
# UN not in financials_clear financials_2015
# U not in financials_clear financials_2015
# MEA not in financials_clear financials_2015
# FSR not in financials_clear financials_2015
# COMS not in financials_clear financials_2015
# IKN not in financials_clear financials_2015
# CSR not in financials_clear financials_2015
# MIR not in financials_clear financials_2015
# RLM not in financials_clear financials_2015
# LIN not in financials_monthly_2015
# BKR not in financials_monthly_2015
# DOW not in financials_monthly_2015
# DXC not in financials_monthly_2015
# PLL not in financials_monthly_2015
# AMCR not in financials_monthly_2015
# BEAM not in financials_monthly_2015
# DELL not in financials_monthly_2015
# HNZ not in financials_monthly_2015
# LXK not in financials_monthly_2015
# HSH not in financials_monthly_2015
# CEG not in financials_monthly_2015
# ROH not in financials_monthly_2015
# MER not in financials_monthly_2015
# ABI not in financials_monthly_2015
# HPC not in financials_monthly_2015
# OMX not in financials_monthly_2015
# TIN not in financials_monthly_2015
# HCR not in financials_monthly_2015
# ADCT not in financials_monthly_2015
# PD not in financials_monthly_2015
# LU not in financials_monthly_2015
# UCL not in financials_monthly_2015
# ONE not in financials_monthly_2015
# AMR not in financials_monthly_2015
# U not in financials_monthly_2015
# WLL not in financials_monthly_2015
# ADPT not in financials_monthly_2015
# FSR not in financials_monthly_2015
# COMS not in financials_monthly_2015
# IKN not in financials_monthly_2015
# MIR not in financials_monthly_2015
# RLM not in financials_monthly_2015
# SIAL not in financials_monthly_2016
# SWY not in financials_monthly_2016
# RSH not in financials_monthly_2016
# EDS not in financials_monthly_2016
# TRW not in financials_monthly_2016
# MEA not in financials_monthly_2016
# LIN not in financials_clear financials_2016
# BKR not in financials_clear financials_2016
# DOW not in financials_clear financials_2016
# STJ not in financials_clear financials_2016
# EMC not in financials_clear financials_2016
# DXC not in financials_clear financials_2016
# SIAL not in financials_clear financials_2016
# PLL not in financials_clear financials_2016
# SWY not in financials_clear financials_2016
# AMCR not in financials_clear financials_2016
# BEAM not in financials_clear financials_2016
# HNZ not in financials_clear financials_2016
# LXK not in financials_clear financials_2016
# HSH not in financials_clear financials_2016
# CEG not in financials_clear financials_2016
# GAS not in financials_clear financials_2016
# RSH not in financials_clear financials_2016
# ROH not in financials_clear financials_2016
# MER not in financials_clear financials_2016
# ABI not in financials_clear financials_2016
# HPC not in financials_clear financials_2016
# EDS not in financials_clear financials_2016
# OMX not in financials_clear financials_2016
# TIN not in financials_clear financials_2016
# ADCT not in financials_clear financials_2016
# PD not in financials_clear financials_2016
# LU not in financials_clear financials_2016
# UCL not in financials_clear financials_2016
# ONE not in financials_clear financials_2016
# AM not in financials_clear financials_2016
# AMR not in financials_clear financials_2016
# TRW not in financials_clear financials_2016
# U not in financials_clear financials_2016
# MEA not in financials_clear financials_2016
# ADPT not in financials_clear financials_2016
# FSR not in financials_clear financials_2016
# COMS not in financials_clear financials_2016
# IKN not in financials_clear financials_2016
# CSR not in financials_clear financials_2016
# MIR not in financials_clear financials_2016
# RLM not in financials_clear financials_2016
# LIN not in financials_monthly_2016
# BKR not in financials_monthly_2016
# DOW not in financials_monthly_2016
# DXC not in financials_monthly_2016
# SIAL not in financials_monthly_2016
# PLL not in financials_monthly_2016
# SWY not in financials_monthly_2016
# AMCR not in financials_monthly_2016
# BEAM not in financials_monthly_2016
# DELL not in financials_monthly_2016
# HNZ not in financials_monthly_2016
# HSH not in financials_monthly_2016
# CEG not in financials_monthly_2016
# RSH not in financials_monthly_2016
# ROH not in financials_monthly_2016
# MER not in financials_monthly_2016
# ABI not in financials_monthly_2016
# HPC not in financials_monthly_2016
# EDS not in financials_monthly_2016
# OMX not in financials_monthly_2016
# TIN not in financials_monthly_2016
# HCR not in financials_monthly_2016
# ADCT not in financials_monthly_2016
# PD not in financials_monthly_2016
# LU not in financials_monthly_2016
# UCL not in financials_monthly_2016
# ONE not in financials_monthly_2016
# TRW not in financials_monthly_2016
# U not in financials_monthly_2016
# WLL not in financials_monthly_2016
# MEA not in financials_monthly_2016
# ADPT not in financials_monthly_2016
# FSR not in financials_monthly_2016
# COMS not in financials_monthly_2016
# IKN not in financials_monthly_2016
# MIR not in financials_monthly_2016
# RLM not in financials_monthly_2016
# EMC not in financials_monthly_2017
# LXK not in financials_monthly_2017
# GAS not in financials_monthly_2017
# SGI not in financials_monthly_2017
# LIN not in financials_clear financials_2017
# BCR not in financials_clear financials_2017
# SPLS not in financials_clear financials_2017
# DOW not in financials_clear financials_2017
# STJ not in financials_clear financials_2017
# EMC not in financials_clear financials_2017
# DXC not in financials_clear financials_2017
# SIAL not in financials_clear financials_2017
# PLL not in financials_clear financials_2017
# SWY not in financials_clear financials_2017
# AMCR not in financials_clear financials_2017
# BEAM not in financials_clear financials_2017
# HNZ not in financials_clear financials_2017
# LXK not in financials_clear financials_2017
# HSH not in financials_clear financials_2017
# CEG not in financials_clear financials_2017
# GAS not in financials_clear financials_2017
# RSH not in financials_clear financials_2017
# ROH not in financials_clear financials_2017
# MER not in financials_clear financials_2017
# KATE not in financials_clear financials_2017
# ABI not in financials_clear financials_2017
# HPC not in financials_clear financials_2017
# EDS not in financials_clear financials_2017
# OMX not in financials_clear financials_2017
# TIN not in financials_clear financials_2017
# ADCT not in financials_clear financials_2017
# PD not in financials_clear financials_2017
# LU not in financials_clear financials_2017
# UCL not in financials_clear financials_2017
# ONE not in financials_clear financials_2017
# TRW not in financials_clear financials_2017
# U not in financials_clear financials_2017
# MEA not in financials_clear financials_2017
# ADPT not in financials_clear financials_2017
# FSR not in financials_clear financials_2017
# COMS not in financials_clear financials_2017
# IKN not in financials_clear financials_2017
# SGI not in financials_clear financials_2017
# CSR not in financials_clear financials_2017
# MIR not in financials_clear financials_2017
# RLM not in financials_clear financials_2017
# LIN not in financials_monthly_2017
# DOW not in financials_monthly_2017
# EMC not in financials_monthly_2017
# SIAL not in financials_monthly_2017
# PLL not in financials_monthly_2017
# SWY not in financials_monthly_2017
# AMCR not in financials_monthly_2017
# BEAM not in financials_monthly_2017
# DELL not in financials_monthly_2017
# HNZ not in financials_monthly_2017
# LXK not in financials_monthly_2017
# HSH not in financials_monthly_2017
# CEG not in financials_monthly_2017
# GAS not in financials_monthly_2017
# RSH not in financials_monthly_2017
# ROH not in financials_monthly_2017
# MER not in financials_monthly_2017
# ABI not in financials_monthly_2017
# HPC not in financials_monthly_2017
# EDS not in financials_monthly_2017
# OMX not in financials_monthly_2017
# HCR not in financials_monthly_2017
# ADCT not in financials_monthly_2017
# PD not in financials_monthly_2017
# LU not in financials_monthly_2017
# UCL not in financials_monthly_2017
# ONE not in financials_monthly_2017
# TRW not in financials_monthly_2017
# U not in financials_monthly_2017
# WLL not in financials_monthly_2017
# MEA not in financials_monthly_2017
# ADPT not in financials_monthly_2017
# FSR not in financials_monthly_2017
# COMS not in financials_monthly_2017
# IKN not in financials_monthly_2017
# SGI not in financials_monthly_2017
# MIR not in financials_monthly_2017
# RLM not in financials_monthly_2017
# BCR not in financials_monthly_2018
# SPLS not in financials_monthly_2018
# STJ not in financials_monthly_2018
# KATE not in financials_monthly_2018
# TIN not in financials_monthly_2018
# VFC not in financials_clear financials_2018
# BCR not in financials_clear financials_2018
# SPLS not in financials_clear financials_2018
# DOW not in financials_clear financials_2018
# STJ not in financials_clear financials_2018
# EMC not in financials_clear financials_2018
# SIAL not in financials_clear financials_2018
# SWY not in financials_clear financials_2018
# AMCR not in financials_clear financials_2018
# BEAM not in financials_clear financials_2018
# HNZ not in financials_clear financials_2018
# LXK not in financials_clear financials_2018
# HSH not in financials_clear financials_2018
# CEG not in financials_clear financials_2018
# GAS not in financials_clear financials_2018
# NSM not in financials_clear financials_2018
# RSH not in financials_clear financials_2018
# ROH not in financials_clear financials_2018
# MER not in financials_clear financials_2018
# KATE not in financials_clear financials_2018
# ABI not in financials_clear financials_2018
# HPC not in financials_clear financials_2018
# EDS not in financials_clear financials_2018
# OMX not in financials_clear financials_2018
# TIN not in financials_clear financials_2018
# ADCT not in financials_clear financials_2018
# PD not in financials_clear financials_2018
# LU not in financials_clear financials_2018
# UCL not in financials_clear financials_2018
# AMR not in financials_clear financials_2018
# TRW not in financials_clear financials_2018
# U not in financials_clear financials_2018
# MEA not in financials_clear financials_2018
# ADPT not in financials_clear financials_2018
# FSR not in financials_clear financials_2018
# DNB not in financials_clear financials_2018
# COMS not in financials_clear financials_2018
# IKN not in financials_clear financials_2018
# SGI not in financials_clear financials_2018
# CSR not in financials_clear financials_2018
# MIR not in financials_clear financials_2018
# BCR not in financials_monthly_2018
# SPLS not in financials_monthly_2018
# DOW not in financials_monthly_2018
# STJ not in financials_monthly_2018
# EMC not in financials_monthly_2018
# SIAL not in financials_monthly_2018
# SWY not in financials_monthly_2018
# AMCR not in financials_monthly_2018
# BEAM not in financials_monthly_2018
# DELL not in financials_monthly_2018
# HNZ not in financials_monthly_2018
# LXK not in financials_monthly_2018
# HSH not in financials_monthly_2018
# CEG not in financials_monthly_2018
# GAS not in financials_monthly_2018
# RSH not in financials_monthly_2018
# ROH not in financials_monthly_2018
# MER not in financials_monthly_2018
# KATE not in financials_monthly_2018
# ABI not in financials_monthly_2018
# HPC not in financials_monthly_2018
# EDS not in financials_monthly_2018
# OMX not in financials_monthly_2018
# TIN not in financials_monthly_2018
# HCR not in financials_monthly_2018
# ADCT not in financials_monthly_2018
# PD not in financials_monthly_2018
# LU not in financials_monthly_2018
# UCL not in financials_monthly_2018
# TRW not in financials_monthly_2018
# U not in financials_monthly_2018
# WLL not in financials_monthly_2018
# MEA not in financials_monthly_2018
# ADPT not in financials_monthly_2018
# COMS not in financials_monthly_2018
# IKN not in financials_monthly_2018
# SGI not in financials_monthly_2018
# MIR not in financials_monthly_2018
# CA not in financials_monthly_2019
# SVU not in financials_monthly_2019
# NSM not in financials_monthly_2019
# KMG not in financials_monthly_2019
# LLTC not in financials_monthly_2001
# STCN not in financials_monthly_2004
# MFE not in financials_monthly_2004
# LLTC not in financials_monthly_2006
# ADCT not in financials_monthly_2006
# STCN not in financials_monthly_2007
# ADCT not in financials_monthly_2007
# COMS not in financials_monthly_2009
# APOL not in financials_monthly_2010
# ATML not in financials_monthly_2010
# LLTC not in financials_monthly_2010
# LLTC not in financials_monthly_2011
# APOL not in financials_monthly_2011
# APOL not in financials_monthly_2012
# APOL not in financials_monthly_2013
# STRZA not in financials_monthly_2013
# STRZA not in financials_monthly_2014
# APOL not in financials_monthly_2014
# STRZA not in financials_monthly_2015
# LLTC not in financials_monthly_2015
