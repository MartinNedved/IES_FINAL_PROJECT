# %% [markdown]
# # Web mining Aplha Vantage
#
# https://www.alphavantage.co/
#
# This module mines data in json and converts them with pandas into 2 json files - overview of each company and time series of the price for each stock

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
import time
import copy
import pickle


list_tickers=["MU", "LKQ", "AVP", "HRS", "PCG", "NOVL", "KMB", "PPL", "ALLE", "CEG", "FITB", "COTY", "FRT", "MCHP", "AYI", "UNM", "DD", "CF", "WAT", "DLTR", "VMC", "MET", "SBUX", "TLAB", "PTV", "PVH", "HFC", "PNC", "TSN", "DOW", "CXO", "ROL", "CCL", "J", "NFLX", "ADM", "ITW", "MS", "HRB", "DRI", "GOOGL", "FBHS", "IVZ", "IEX", "VRTX", "JEF", "PSA", "JKHY", "LUV", "SNA", "KFT", "PCLN", "NWSA", "BMS", "XEC", "INTU", "ZBH", "MIL", "LW", "BR", "URBN", "LXK", "CLF", "JDSU", "SIVB", "MSFT", "AVB", "KSS", "NWS", "NSC", "HOT", "LVLT", "ADS", "AIG", "SVU", "CRM", "PAYX", "RAD", "ED", "MSI", "SYK", "LYB", "ZTS", "BK", "PCL", "CTVA", "CAH", "SJM", "TMUS", "BKR", "CHRW", "OTIS", "SBL", "HOLX", "CMG", "CTLT", "TMO", "AWK", "PEAK", "PCS", "XRAY", "ALGN", "CB", "WHR", "FAST", "GL", "APOL", "KR", "RE", "TJX", "CHK", "FII", "SLR", "STT", "MON", "FISV", "COG", "DAL", "MCK", "DTE", "M", "LSI", "NEM", "VNO", "HAR", "MSCI", "MNST", "OKE", "F", "ILMN", "NLOK", "BRCM", "CPRT", "ETN", "PNR", "BLK", "STZ", "DRE", "BEAM", "HWM", "TFC", "DISH", "WFC", "MWW", "NTRS", "ITT", "ANR", "TSO", "ABS", "SII", "AJG", "ANF", "CME", "XYL", "ANDV", "MI", "DG", "RX", "JNY", "EK", "TEG", "DV", "SBAC", "QRVO", "MRO", "DISCK", "APA", "EQR", "SE", "AZO", "APTV", "AIZ", "WMT", "IDXX", "LLL", "ICE", "NEE", "SLB", "ABT", "LVS", "EVRG", "CDW", "UNH", "MJN", "ODP", "HSIC", "TSS", "DVN", "SRCL", "SCHW", "HAL", "HES", "PLD", "NSM", "WY", "TWTR", "PNW", "ZBRA", "VZ", "KSE", "QCOM", "DNR", "MAT", "KBH", "LHX", "FSLR", "ESRX", "MKC", "RHI", "Q", "PKI", "CTXS", "UPS", "REG", "MHK", "RJF", "RSH", "ULTA", "POOL", "R", "HCA", "LUMN", "AKAM", "JBHT", "CIEN", "ENDP", "RCL", "AVY", "PETM", "FOX", "CMCSA", "CSX", "CNC", "SHW", "SIAL", "GNW", "ATI", "PM", "TSG", "ALTR", "EXPE", "GT", "CNP", "IFF", "EP", "ABK", "BSX", "TE", "ANET", "NDAQ", "LO", "CFG", "ISRG", "ROK", "XOM", "STJ", "LYV", "GR", "AMG", "IPG", "SHLD", "FB", "AMZN", "EW", "ARE", "TXT", "JNS", "EOG", "TEL", "ECL", "FTV", "FLR", "FE", "CSCO", "LB", "LH", "REGN", "NBR", "BA", "BF.B", "HON", "MGM", "MOS", "XRX", "HPQ", "IBM", "SWN", "CTSH", "UAL", "CMCSK", "FNM", "SAIC", "VIAB", "JNPR", "PWR", "CHD", "TDC", "EFX", "BLL", "JWN", "JBL", "EA", "HUM", "PEP", "POM", "AMP", "L", "AMGN", "CERN", "BWA", "FRC", "KG", "NE", "ORCL", "ALK", "ALB", "ES", "MMM
RCX", "SO", "TYL", "LLTC", "GMCR", "WFR", "EXPD", "TWX", "CVS", "PG", "AXP", "MUR", "PBI", "NYX", "INTC", "MAC", "NCLH", "WST", "ROP", "CBRE", "THC", "TDY", "RDC", "WCG", "AN", "NUE", "OMC", "AON", "PBCT", "FANG", "WMB", "STR", "GIS", "PGN", "XTO", "VTRS", "COV", "HNZ", "CL", "PRU", "EL", "T", "A", "RTX", "SRE", "VLO", "NFX", "SWK", "BTU", "KIM", "FOSL", "BIG", "NAVI", "FTR", "ACAS", "CINF", "IRM", "SAI", "MNK", "CVC", "DTV", "COP", "TRB", "GGP", "DE", "BIIB", "YHOO", "BJS", "EXC", "SYY", "MMI", "COO", "PGR", "MDT", "ACN", "ALL", "DELL", "WRB", "LDW", "TRIP", "MPC", "FIS", "LNT", "MHS", "CSRA", "SGP", "CMI", "SLG", "FRX", "HST", "FRE", "FCX"]
list_tickers_2=copy.deepcopy(list_tickers) 
list_tickers_help=copy.deepcopy(list_tickers) 


with open(file_name,'rb') as my_file_obj:
    api_key=pickle.load(my_file_obj) 


def url_def_series(api,ticker):
    
    url=f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY_ADJUSTED&symbol={ticker}&apikey={api}'
    text_html=requests.get(url)
    return(text_html.json())

def url_def_overview(api,ticker):
    
    url=f'https://www.alphavantage.co/query?function=OVERVIEW&symbol={ticker}&apikey={api}'
    text_html=requests.get(url)
    return(text_html.json())


    
    

company_overview_list={}
monthly_adjusted_stock_timeseries={}

len_tic=len(list_tickers)
ticker=''
json_timeseries=''
json_overview=''
over_notfound=0
over_found=0
series_notfound=0
series_found=0

not_found_series=[]
not_found_overview=[]
found_series=[]
found_overview=[]
x=0

# for i in range((round(len_tic/4))+1):
    

#     for j in range(len(api_key)):
#             if (len(list_tickers)!=0) and (x<=500):
                
#                 ticker=list_tickers.pop(0)
                
#                 json_timeseries=url_def_series(api_key[j],ticker)
                
#                 x+=1
#                 print(x)
                
#                 if  (json_timeseries != {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_MONTHLY_ADJUSTED.'}):
#                         monthly_adjusted_stock_timeseries[ticker] = json_timeseries
#                         found_series.append(ticker)
#                 else:
#                     not_found_series.append(ticker)
                    
#                 time.sleep(13)
            
#             else:
#                 break
                

# for i in range((round(len_tic/4))+1):
    

#        for j in range(len(api_key)):
        
#             if (len(list_tickers_2)!=0) and (x<=500):
                
#                 ticker=list_tickers_2.pop(0)
                
#                 json_overview=url_def_overview(api_key[j],ticker)
                
#                 x+=1
#                 print(x)
                
#                 if (json_overview != {}): 
#                         company_overview_list[ticker] = json_overview
#                         found_overview.append(ticker)
#                 else:
#                      not_found_overview.append(ticker)
                
#                 time.sleep(13)
            
#             else:
#                 break

                
# print(len(not_found_series))
# print(not_found_series)
# print(len(found_series))
# print(found_series)
# print(len(not_found_overview))
# print(not_found_overview)
# print(len(found_overview))
# print(found_overview)

#print(company_overview_list)
#print(monthly_adjusted_stock_timeseries)

#with open("company_overview_list_2.json", "w") as json_file:
            #json.dump(company_overview_list, json_file)
        
#with open("monthly_adjusted_stock_timeseries_2.json", "w") as json_file:
             #json.dump(monthly_adjusted_stock_timeseries, json_file)        
                
                
                

#price_data = raw_data['Time Series (Daily)']

#print(price_data)

# price_data = data['Time Series (15min)']

# for key, value in price_data.items():

# for inner_key, inner_value in value.items():
 
# price = value['4. close']

# myDict[key] = price
